# %%
import pandas as pd

# %%
control = pd.read_csv('../data/control copy.csv')
treatment = pd.read_csv('../data/treatment copy.csv')
history = pd.read_csv('../data/wh_history_full.csv')

# %%
control_employees = set(control['rec_id'].unique())
treatment_employees = set(treatment['rec_id'].unique())

# %%
len(control_employees)
# Out:
# 22

# %%
len(treatment_employees)
# Out:
# 5

# %%
history = pd.read_csv('../data/wh_history_full.csv')
history_set = set(history['pk_user'].unique())

# %%
pattern = r"\bVP\b|\bV\.P\.\b|\bVice\b|\bVice[- ]President\b|\bSVP\b|\bEVP\b|\bAVP\b|\bRVP\b|\bDVP\b"

vp_rows = history[
    history["job_title"].str.contains(pattern, case=False, regex=True, na=False)
]

vp_rows
# Out:
#         pk_user  fk_direct_manager  \
# 6         67028           303093.0
# 7         67028         27060221.0
# 8         67028            67036.0
# 9         67028           303093.0
# 10        67028           303093.0
# ...         ...                ...
# 11436  27362927            69005.0
# 11577  28265674         21740703.0
# 11578  28265674         21740703.0
# 11625  28543723          2624695.0
# 11709  29239901          4065764.0
#
#                                                job_title effective_start_date  \
# 6                               VP, Financial Controller           2023-01-16
# 7                               VP, Financial Controller           2024-02-27
# 8                               VP, Financial Controller           2024-03-11
# 9                               VP, Financial Controller           2024-03-15
# 10                            Vice President, Controller           2024-08-27
# ...                                                  ...                  ...
# 11436                Vice President, Product Engineering           2024-08-27
# 11577  Senior Vice President, Customer Account Manage...           2024-10-11
# 11578                           SVP, Customer Excellence           2025-06-12
# 11625                                     VP, Operations           2024-08-27
# 11709              Vice President, Sales - North America           2024-12-06
#
#       effective_end_date
# 6             2023-02-01
# 7             2024-03-01
# 8             2024-03-15
# 9             2024-03-18
# 10            2024-08-28
# ...                  ...
# 11436         2024-08-28
# 11577         2024-10-17
# 11578         2025-06-13
# 11625         2024-08-28
# 11709         2024-12-10
#
# [223 rows x 5 columns]

# %%
vp_set = set(vp_rows['pk_user'].unique())

# %%
len(history_set)
# Out:
# 2684

# %%
len(vp_set)
# Out:
# 68

# %%
(treatment_employees & vp_set)
# Out:
# {np.int64(67028),
#  np.int64(5460545),
#  np.int64(7089735),
#  np.int64(7569574),
#  np.int64(10792543)}

# %%
(control_employees & vp_set)
# Out:
# set()

# %%
(treatment_employees & vp_set) - (control_employees & vp_set)
# Out:
# {np.int64(67028),
#  np.int64(5460545),
#  np.int64(7089735),
#  np.int64(7569574),
#  np.int64(10792543)}

# %%
len(treatment_employees & vp_set)
# Out:
# 5

# %%
control_employees
# Out:
# {np.int64(139522),
#  np.int64(2092856),
#  np.int64(2800139),
#  np.int64(3218400),
#  np.int64(3390854),
#  np.int64(5248156),
#  np.int64(7249066),
#  np.int64(7420550),
#  np.int64(8209895),
#  np.int64(8554955),
#  np.int64(9213055),
#  np.int64(9372807),
#  np.int64(10785359),
#  np.int64(10968258),
#  np.int64(10973462),
#  np.int64(11120885),
#  np.int64(11168127),
#  np.int64(11837898),
#  np.int64(11989802),
#  np.int64(12733321),
#  np.int64(13519224),
#  np.int64(15809526)}

# %%
history[history['pk_user'] == 29239901]
# Out:
#         pk_user  fk_direct_manager                              job_title  \
# 11709  29239901          4065764.0  Vice President, Sales - North America
#
#       effective_start_date effective_end_date
# 11709           2024-12-06         2024-12-10

# %%
control_df[control_df['nom_id'] ==67028]
# Out:
#       Unnamed: 0    rec_id  nom_id   award_id      ah_id    link_id  \
# 575        73965  15809526   67028  158924239  156856243  7340989.0
# 650        80514  15809526   67028  154353624  152035874  6964670.0
# 1186      140725  15809526   67028  120674900  118802758  4031264.0
# 1329      151194  15809526   67028  115956021  114236112  3650137.0
# 1395      158734  15809526   67028  112435833  110811301  3417887.0
# 2279      208813  15809526   67028   85018823   83862523        NaN
# 2727      227204   8554955   67028   75451700   74459914  1028977.0
# 2729      227236   9213055   67028   75451933   74451135  1028991.0
# 2730      227240  10973462   67028   75451932   74450142  1028991.0
# 4116      276044   7249066   67028   52020868   51710845   195146.0
# 4515      292166   7249066   67028   44431868   44071050        NaN
# 5408      329238   3390854   67028   25557245   25554888        NaN
# 5560      337078   3390854   67028   21363144   21487866        NaN
#
#       award_private  product_id                                title  \
# 575               0         620   Superb execution in a very busy Q1
# 650               0         620            Plan, prepare and execute
# 1186              0         620              Investing in our people
# 1329              0         620                         Sept offsite
# 1395              0         620        Super progress ... keep it up
# 2279              0         620  Adding value left, right and centre
# 2727              0         620               Zoom around Tues night
# 2729              0         620          Wednesday night Zoom-around
# 2730              0         620          Wednesday night Zoom-around
# 4116              0         620              Happy Finance Customers
# 4515              0         620                 Keeping us compliant
# 5408              0         620         INTUIT 'WOO-HOO & THANK YOU'
# 5560              0         620       Rebuilding Customer Confidence
#
#                                                 message  award_date
# 575   Thank you all for leading your teams during wh...  2024-03-25
# 650   Well done Team in making our YE financial repo...  2024-01-31
# 1186  Thank you all for taking the time and effort t...  2022-11-25
# 1329  Thanks you all for taking the time to bring yo...  2022-09-27
# 1395  Wonderful work done to date in getting our int...  2022-08-18
# 2279  Catriona, you have truly hit the ground runnin...  2021-07-29
# 2727  Thanks everyone for showing up and contributin...  2021-01-29
# 2729  Thanks everyone for showing up and contributin...  2021-01-29
# 2730  Thanks everyone for showing up and contributin...  2021-01-29
# 4116  Thank you all for your part in analysing, deve...  2019-07-20
# 4515  Thanks Orlagh for working with the various int...  2018-12-01
# 5408  It's been quite a journey to get here but we o...  2016-12-10
# 5560  Thanks to you we are starting to regain the po...  2016-05-07

# %%
len(vp_set)
# Out:
# 68
